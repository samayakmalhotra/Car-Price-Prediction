# %%
#Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/CarPrice.csv') #Reading the CSV file

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape #To get number of rows and columns
# Out:
# (205, 26)

# %%
df.nunique() #Number of unique values in each columns
# Out:
# car_ID              205
# symboling             6
# CarName             147
# fueltype              2
# aspiration            2
# doornumber            2
# carbody               5
# drivewheel            3
# enginelocation        2
# wheelbase            53
# carlength            75
# carwidth             44
# carheight            49
# curbweight          171
# enginetype            7
# cylindernumber        7
# enginesize           44
# fuelsystem            8
# boreratio            38
# stroke               37
# compressionratio     32
# horsepower           59
# peakrpm              23
# citympg              29
# highwaympg           30
# price               189
# dtype: int64

# %%
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.drop(['fuelsystem','cylindernumber','enginetype','aspiration','symboling','car_ID'],inplace=True,axis=1) #Dropping irrelevant columns.

# %%
data = df
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CarName           205 non-null    object
#  1   fueltype          205 non-null    object
#  2   doornumber        205 non-null    object
#  3   carbody           205 non-null    object
#  4   drivewheel        205 non-null    object
#  5   enginelocation    205 non-null    object
#  6   wheelbase         205 non-null    float64
#  7   carlength         205 non-null    float64
#  8   carwidth          205 non-null    float64
#  9   carheight         205 non-null    float64
#  10  curbweight        205 non-null    int64
#  11  enginesize        205 non-null    int64
#  12  boreratio         205 non-null    float64
#  13  stroke            205 non-null    float64
#  14  compressionratio  205 non-null    float64
#  15  horsepower        205 non-null    int64
# ...

# %%
#Dropping irrelevant columns from the dataset
data.drop(['CarName','fueltype','doornumber','carbody','drivewheel','enginelocation'],axis=1,inplace=True)

# %%
feature = df.dtypes == np.object #Storing data that has categorical data into feature variable
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.

# %%
#Creating array of columns having data type of object
feature = df.dtypes[df.dtypes == np.object]
feature = feature.index.tolist()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
df_dum = pd.get_dummies(df,columns=feature,drop_first=True) #To convert categorical data into numerical data

# %%
df = df.drop(df[feature],axis=1) #Drop categorical feature as we have numerical data in our dataset

# %%
pd.concat([df,df_dum],axis=1) #Adding 2 dataframes columnswise
# Out:
#      wheelbase  carlength  carwidth  carheight  curbweight  enginesize  \
# 0         88.6      168.8      64.1       48.8        2548         130
# 1         88.6      168.8      64.1       48.8        2548         130
# 2         94.5      171.2      65.5       52.4        2823         152
# 3         99.8      176.6      66.2       54.3        2337         109
# 4         99.4      176.6      66.4       54.3        2824         136
# ..         ...        ...       ...        ...         ...         ...
# 200      109.1      188.8      68.9       55.5        2952         141
# 201      109.1      188.8      68.8       55.5        3049         141
# 202      109.1      188.8      68.9       55.5        3012         173
# 203      109.1      188.8      68.9       55.5        3217         145
# 204      109.1      188.8      68.9       55.5        3062         141
#
#      boreratio  stroke  compressionratio  horsepower  ...  curbweight  \
# ...

# %%
small_df = df.loc[:,['wheelbase','carlength','carwidth','carheight','boreratio','stroke','compressionratio','price']]

# %%
sns.pairplot(small_df) #Correlation(Relation between model and what model can be applied)

# %%
sns.histplot(df['compressionratio'],bins=25) #Display single column and we see positive skewness

# %%
sns.histplot(df['wheelbase'],bins=25)

# %%
mask = df.dtypes == np.float #Storing columns having datatype of float
float_cols = df.columns[mask]

skew_limit = 0.75 # define a limit above which we will log transform
skew_vals = df[float_cols].skew()
skew_vals
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# wheelbase           1.050214
# carlength           0.155954
# carwidth            0.904003
# carheight           0.063123
# boreratio           0.020156
# stroke             -0.689705
# compressionratio    2.610862
# price               1.777678
# dtype: float64

# %%
skew_cols = (skew_vals.sort_values(ascending=False).to_frame().rename(columns={0:'Skew'}).query('abs(Skew) > {}'.format(skew_limit)))
skew_cols #Only displays columns with skewness >0.75
# Out:
#                       Skew
# compressionratio  2.610862
# price             1.777678
# wheelbase         1.050214
# carwidth          0.904003

# %%
for col in skew_cols.index.values:
    if col == "price":
        continue
    df[col] = df[col].apply(np.log1p) #Convert the skewed columns to Normal distibition

# %%
sns.histplot(df['compressionratio'],bins=25) #Now we see that the values have come closer

# %%
mask = df.dtypes == np.float
float_cols = df.columns[mask]

skew_limit = 0.75 # define a limit above which we will log transform
skew_vals = df[float_cols].skew()
skew_vals
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# wheelbase           0.885024
# carlength           0.155954
# carwidth            0.815331
# carheight           0.063123
# boreratio           0.020156
# stroke             -0.689705
# compressionratio    2.379056
# price               1.777678
# dtype: float64

# %%
#HeatMap shows strength as well as direction of correlation
plt.figure(figsize=(40,40))
sns.heatmap(df.corr(method ='pearson'),cmap='PuBu',annot=True,linewidths=0.5)
plt.show()

# %%
X = df.drop(['wheelbase','carheight'],axis=1) #For our model correlation is not good so we remove the columns having less impact on predicted column. Also helps reducing noise

# %%
X = X.drop('price',axis=1) #Adding independent features in X
y = df['price'] #Target/Label Column

# %%
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import GridSearchCV, train_test_split, KFold
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
#Splitting into test and training
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=72018)

# %%
#Baseline model for regression
#Mean price for a car
y_pred= y_train.mean()
y_pred
# Out:
# 12755.242921568626

# %%
y_pred4=y_test.mean()
y_pred4
# Out:
# 14811.028846153846

# %%
from random import seed
from random import randrange

# zero rule algorithm for regression
def zero_rule_algorithm_regression(y_pred, y_pred4):
	output_values = [row[-1] for row in y_pred]
	prediction = sum(output_values) / float(len(output_values))
	predicted = [prediction for i in range(len(y_pred4))]
	return predicted

# %%
y_pred2=[y_pred]*len(y_train)

# %%
#Mean Absolute Error for training data baseline
mean_absolute_error= mean_absolute_error(y_train,y_pred2)
mean_absolute_error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-9b8c4168700c> in <module>()
#       1 #Mean Absolute Error for training data baseline
# ----> 2 mean_absolute_error= mean_absolute_error(y_train,y_pred2)
#       3 mean_absolute_error
#
# TypeError: 'numpy.float64' object is not callable

# %%
#Mean Squared Error for training data baseline
mean_squared_error= mean_squared_error(y_train,y_pred2)
mean_squared_error
# Out:
# 49380683.33487074

# %%
#Prediction for y test and MSE,MAE
from sklearn import metrics

y_pred3=[y_pred4] * len(y_test)
mae=mean_absolute_error(y_test,y_pred3)
mse=mean_squared_error(y_test,y_pred3)

print(f"MAE:{mae} \nmse: {mse}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-af5e8fcfa98a> in <module>()
#       3
#       4 y_pred3=[y_pred4] * len(y_test)
# ----> 5 mae=mean_absolute_error(y_test,y_pred3)
#       6 mse=mean_squared_error(y_test,y_pred3)
#       7
#
# TypeError: 'numpy.float64' object is not callable

# %%
#Standardizing the data
s = StandardScaler()
X_train_s = s.fit_transform(X_train)
X_test_s = s.transform(X_test)

# %%
#Linear Regression
lr = LinearRegression()
lr = lr.fit(X_train_s,y_train)
pred = lr.predict(X_test_s)
r2_score(y_test,pred) #Accuracy score

# %%
y_test.mean()

# %%
kf = KFold(shuffle=True,random_state=72018,n_splits=3)

# %%
#Decision Tree Model
from sklearn.tree import DecisionTreeRegressor
dt = DecisionTreeRegressor()
dt = dt.fit(X_train,y_train)
dt_pred = dt.predict(X_test)

# %%
r2_score(y_test,dt_pred) #Higher accuracy compared to other models

# %%
arr = X_test.iloc[2,:] #Selecting one sample from test dataset to compare and make prediction on it to check if predcition is good or no.
arr

# %%
#Reshaping the array
a = np.array(arr)
a = a.reshape(1,-1)

# %%
f_pred = dt.predict(a)

# %%
y_test[0:3]

# %%
f_pred #So we see the predicted value is close to the actual value.
